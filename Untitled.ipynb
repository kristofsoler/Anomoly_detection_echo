# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
train_df
# Out:
#      state  account_length      area_code international_plan voice_mail_plan  \
# 0       OH             107  area_code_415                 no             yes
# 1       NJ             137  area_code_415                 no              no
# 2       OH              84  area_code_408                yes              no
# 3       OK              75  area_code_415                yes              no
# 4       MA             121  area_code_510                 no             yes
# ...    ...             ...            ...                ...             ...
# 4245    MT              83  area_code_415                 no              no
# 4246    WV              73  area_code_408                 no              no
# 4247    NC              75  area_code_408                 no              no
# 4248    HI              50  area_code_408                 no             yes
# 4249    VT              86  area_code_415                 no             yes
#
# ...

# %%
p50_account_length_by_state = train_df.\
    groupby("state").\
    median()["account_length"]

# %%
p50_day_minutes_by_state = train_df.\
    groupby("state").\
    median()["total_day_minutes"]

# %%
git clone [https://github.com/kristofsoler/datascience.git]
# Out:
#   File "<ipython-input-7-6eabd9a21854>", line 1
#     git clone [https://github.com/kristofsoler/datascience.git]
#         ^
# SyntaxError: invalid syntax
